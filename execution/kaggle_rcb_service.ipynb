# %% [markdown]
# # RCB 2.0 Payment Management Service
# This notebook automates payment tracking and reminders for the RCB 2.0 WhatsApp group.

# %%
# !pip install whatsapp-api-client-python python-dotenv

# %%
import os
from kaggle_secrets import UserSecretsClient

# Set up credentials from Kaggle Secrets
user_secrets = UserSecretsClient()
os.environ["GREENAPI_ID_INSTANCE"] = user_secrets.get_secret("GREENAPI_ID_INSTANCE")
os.environ["GREENAPI_API_TOKEN"] = user_secrets.get_secret("GREENAPI_API_TOKEN")

# %%
# Copy necessary files from the repository or define them here
# For simplicity in the first run, we define the core logic or download it.

# %%
# Run the analyzer (10 PM IST schedule in Kaggle)
# !python rcb_payment_manager.py --analyze

# %%
# Run the reminder (8 AM IST schedule in Kaggle)
# !python rcb_payment_manager.py --send
